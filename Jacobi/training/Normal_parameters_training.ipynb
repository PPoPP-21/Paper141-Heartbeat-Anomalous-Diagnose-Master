# %% [markdown]
# # Experiment-training|Jacobi

# %% [markdown]
# ### Import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data alignment

# %%
# calculting the fitting value R2
from sklearn.metrics import r2_score
def caculateMse_R2(x,y,p):
    y_pre = [p(i) for i in x]
    score = r2_score(y, y_pre, multioutput='raw_values')
    return score[0]

# merge list，[[x1,y1],[x2,y2],...,[xn,yn]]

def list_set(x,y):
    list=[]
    for i in range(0,len(x)):
        list.append([x[i],y[i]])
    return list

# Extend the short series

def data_set_fix(list,x):
    n=0;
    data=0;
    for i in range(0,len(list)):
        if n==0:
            if list[i][0]==x:
                n=1
                data=list[i][1]
        else:
            list[i][1]=data
    
    return list

# %%
# Single series data alignment method
def align_data_singe(x,y,x1,n):
    
    # fitting,if R2<0.9 do re-fitting
    while True:
        coef = np.polyfit(x,y, n)
        poly_fit = np.poly1d(coef)
        R2 = caculateMse_R2(x,y,poly_fit)
        if n>=19:
            break
        if R2>0.9:
            break
        else:
            n=n+1 
        
    # list
    data_set = list_set(x,y)
    
    # Data alignment
    for i in range(0,len(x1)):
         data_set.append([x1[i],poly_fit(x1[i])])
    
    # sort
    data_set.sort();
    
    return data_set
    
# double seriers alignment
def align_data(x1,y1,x2,y2):
    timeseries1 = align_data_singe(x1,y1,x2,6)
    timeseries2 = align_data_singe(x2,y2,x1,6)
    
   # data fitting（short series align to the long series，tail data mean as the current value）
    if(len(x1)>len(x2)):
        timeseries2 = data_set_fix(timeseries2,x2[-1])
    else:
        timeseries1 = data_set_fix(timeseries1,x1[-1])
    
    return timeseries1,timeseries2

# %% [markdown]
# ### Sequence attribute and feature evaluation algorithm

# %%
# DTW distance
# calculating the weight
def calculate_attenuate_weight(seqLen1, seqLen2, com_ls):
    weight = 0
    for comlen in com_ls:
        weight = weight + comlen / seqLen1 * comlen / seqLen2
    return 1 - weight

# DTW distance
def DTWDistance(s1, s2):
    # acquire std
    sdt = np.std(s1, ddof=1) if np.std(s1, ddof=1) > np.std(s2, ddof=1) else np.std(s2, ddof=1)
    l1 = len(s1)
    l2 = len(s2)
    paths = np.full((l1 + 1, l2 + 1), np.inf)  # assign infinity
    sub_matrix = np.full((l1, l2), 0)  # assign 0
    max_sub_len = 0

    paths[0, 0] = 0
    for i in range(l1):
        for j in range(l2):
            d = s1[i] - s2[j]
            cost = d ** 2
            paths[i + 1, j + 1] = cost + min(paths[i, j + 1], paths[i + 1, j], paths[i, j])
            if np.abs(s1[i] - s2[j]) < sdt:
                if i == 0 or j == 0:
                    sub_matrix[i][j] = 1
                else:
                    sub_matrix[i][j] = sub_matrix[i - 1][j - 1] + 1
                    max_sub_len = sub_matrix[i][j] if sub_matrix[i][j] > max_sub_len else max_sub_len

    paths = np.sqrt(paths)
    s = paths[l1, l2]

    return s

# %%
#LB_Keogh
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return math.sqrt(LB_sum)

# %%
# Similarity
def Dtw_LB_conter(data1,data2,r):
    l=LB_Keogh(data1,data2,r)+DTWDistance(data1,data2)
    return l/2

def getMin(a,b):
    if a<b:
        return a
    else:
        return b

# %%
def timeseries_score(s1,s2,w,r):
    # series:s1，series:s2, w:sliding window size,r:slope sliding window   
    # time ratio
    time_s1_s2 = s2[0][len(s2[0])-1]/s1[0][len(s1[0])-1]
    
       # time ratio via sliding window 
    time_sum=0;
    for i in range(math.ceil(len(s1[0])/w)):
        s1_time = sum(s1[0][i:i+w])
        s2_time = sum(s2[0][i:i+w])
        i=i+w
        time_sum =time_sum + s2_time/s1_time    

    time_sum = time_sum/math.ceil(len(s1[0])/w)
    
        # Mean ratio
    heartbeat_s1 = (sum(s1[1])/len(s1[1]))
    heartbeat_s1_s2 = sum(s2[1])/len(s2[1])/(sum(s1[1])/len(s1[1]))
    
    # Mean ratio via sliding window 
    heartbeat_sum=0;
    for i in range(math.ceil(len(s1[1])/w)):
        s1_heartbeat = sum(s1[1][i:i+w])
        s2_heartbeat = sum(s2[1][i:i+w])
        i=i+w
        heartbeat_sum =heartbeat_sum + s2_heartbeat/s1_heartbeat    

    heartbeat_sum = heartbeat_sum/math.ceil(len(s1[1])/w)
    
    # slope ratio via sliding window
    slope_sum=0;
    for i in range(math.ceil(getMin(len(s1[1])/r,len(s2[1])/r))):
        
        k=i+r
        if(k>len(s1[1])):
            k=len(s1[1])  
        
        s1_slope = (s1[1][i]-s1[1][k])/(s1[0][i]-s1[0][k])
        s2_slope = (s2[1][i]-s2[1][k])/(s2[0][i]-s2[0][k])
        
        i=i+r
        slope_sum =slope_sum + abs(s2_slope/s1_slope)    

    slope_sum = slope_sum/math.ceil(math.ceil(len(s1[1])/r))

    return [time_s1_s2,time_sum,heartbeat_s1,heartbeat_s1_s2,heartbeat_sum,slope_sum]

# %%
def similar_all(x1,y1,x2,y2,tS1,tS2):
    x_p1 =[ tS1[i][0] for i in range(0,len(tS1))]
    y_p1 =[ tS1[i][1] for i in range(0,len(tS1))]
    x_p2 =[ tS2[i][0] for i in range(0,len(tS2))]
    y_p2 =[ tS2[i][1] for i in range(0,len(tS2))]
    
    feature = timeseries_score([x1,y1],[x2,y2],200,20)
    distent = Dtw_LB_conter(y_p1,y_p2,100)
    
    return feature,distent

# %% [markdown]
# ### Experiments - parameter setting

# %% [markdown]
# #### import data

# %%
#import data
import pandas as pd
data = pd.read_excel('./jacobi_normal_1.xlsx',sheet_name=None)
print(len(data))
# Out:
# 16

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('./jacobi_normal_1.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['Timestamp'].copy()[0:999]
    y6 = data[i]['Heartbeat'].copy()[0:999]
    label_name = 'Test sequence:'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()

# %%
def lab(x,y,ll):
    SeriesFeature=[]
    for j in data:
        title_times = "Processing:"+str(ll)+",round:"+str(j)
        print(title_times)
        x2 = data[j]['Timestamp'].copy()[0:999]
        y2 = data[j]['Heartbeat'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)

        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature.append(feature)
           
    # max
    max_time=0;
    local_max_time=0;
    max_hb=0;
    local_max_hb=0;
    local_max_slope=0
    max_dtw_lb=0;

    # min
    min_time=2;
    local_min_time=2;
    min_hb=2;
    local_min_hb=2;
    local_min_slope=2
    min_dtw_lb=9999999999999;
    
    # acquire max-min
    for feature in SeriesFeature:
 
        max_time = max_time  if max_time>feature[0][0] else feature[0][0]
        local_max_time = local_max_time  if local_max_time>feature[0][1] else feature[0][1]
        max_hb = max_hb  if max_hb>feature[0][3] else feature[0][3]
        local_max_hb = local_max_hb  if local_max_hb>feature[0][4] else feature[0][4]
        local_max_slope = local_max_slope  if local_max_slope>feature[0][5] else feature[0][5]
        max_dtw_lb = max_dtw_lb  if max_dtw_lb>feature[1] else feature[1]


        min_time = min_time  if min_time<feature[0][0] else feature[0][0]
        local_min_time = local_min_time  if local_min_time<feature[0][1] else feature[0][1]
        min_hb = min_hb  if min_hb<feature[0][3] else feature[0][3]
        local_min_hb = local_min_hb  if local_min_hb<feature[0][4] else feature[0][4]
        local_min_slope = local_min_slope  if local_min_slope<feature[0][5] else feature[0][5]
        min_dtw_lb = min_dtw_lb  if min_dtw_lb<feature[1] else feature[1]
    
    max_result.append([max_time,local_max_time,max_hb,local_max_hb,local_max_slope,max_dtw_lb])
    min_result.append([min_time,local_min_time,min_hb,local_min_hb,local_min_slope,min_dtw_lb])
    print("------------------------------------",ll)
    print("max",[max_time,local_max_time,max_hb,local_max_hb,local_max_slope,max_dtw_lb])
    print("min",[min_time,local_min_time,min_hb,local_min_hb,local_min_slope,min_dtw_lb])
    print("------------------------------------")

# %%
for ll in data:
    x = data[ll]['Timestamp'].copy()[0:999]
    y = data[ll]['Heartbeat'].copy()[0:999]
    x = np.array(x)
    y = np.array(y)
    max_result=[]
    min_result=[]
    lab(x,y,ll)
# Out:
# Processing:1,round:1
# Processing:1,round:2
# Processing:1,round:3
# Processing:1,round:4
# Processing:1,round:5
# Processing:1,round:6
# Processing:1,round:7
# Processing:1,round:8
# Processing:1,round:9
# Processing:1,round:10
# Processing:1,round:11
# Processing:1,round:12
# Processing:1,round:13
# Processing:1,round:14
# Processing:1,round:15
# Processing:1,round:16
# ------------------------------------ 1
# max [1.0, 1.053008154275961, 1.4345767363402742, 1.887663986708974, 929.9526791040671, 18383880857.236923]
# min [0.7747602790860837, 0.6908280840913466, 1.0, 0.9104875116294318, 1.0, 185.53159081506737]
# ------------------------------------
# Processing:2,round:1
# Processing:2,round:2
# Processing:2,round:3
# Processing:2,round:4
# Processing:2,round:5
# Processing:2,round:6
# Processing:2,round:7
# Processing:2,round:8
# Processing:2,round:9
# Processing:2,round:10
# Processing:2,round:11
# Processing:2,round:12
# Processing:2,round:13
# Processing:2,round:14
# Processing:2,round:15
# Processing:2,round:16
# ------------------------------------ 2
# max [1.0553586391155976, 1.0, 1.4084970898501301, 2.0732626224654216, 11.96947187068455, 2656952676.918719]
# min [0.8176499537771098, 0.6560525583927822, 0.9818206681946653, 1.0, 1.0, 83.6932863870311]
# ------------------------------------
# Processing:3,round:1
# Processing:3,round:2
# Processing:3,round:3
# Processing:3,round:4
# Processing:3,round:5
# Processing:3,round:6
# Processing:3,round:7
# Processing:3,round:8
# Processing:3,round:9
# Processing:3,round:10
# Processing:3,round:11
# Processing:3,round:12
# Processing:3,round:13
# Processing:3,round:14
# Processing:3,round:15
# Processing:3,round:16
# ------------------------------------ 3
# max [1.11685662113303, 1.2844029893117064, 1.2184259599580907, 1.6535042799594284, 34.54402936001565, 178094930.88636273]
# min [0.8652961474881666, 0.8426356701341927, 0.8493278394200073, 0.7975177951751868, 1.0, 197.0934770284298]
# ------------------------------------
# Processing:4,round:1
# Processing:4,round:2
# Processing:4,round:3
# Processing:4,round:4
# Processing:4,round:5
# Processing:4,round:6
# Processing:4,round:7
# Processing:4,round:8
# Processing:4,round:9
# Processing:4,round:10
# Processing:4,round:11
# Processing:4,round:12
# Processing:4,round:13
# Processing:4,round:14
# Processing:4,round:15
# Processing:4,round:16
# ------------------------------------ 4
# max [1.1182243000922591, 1.3175207574101069, 1.0854363203580433, 1.1219058722111395, 5.12503795444588, 144531669.67287984]
# min [0.8663557708203193, 0.8643625810309367, 0.756624788944426, 0.5412567793614802, 0.33454431505232457, 828.9986630171898]
# ------------------------------------
# Processing:5,round:1
# Processing:5,round:2
# Processing:5,round:3
# Processing:5,round:4
# Processing:5,round:5
# Processing:5,round:6
# Processing:5,round:7
# Processing:5,round:8
# Processing:5,round:9
# Processing:5,round:10
# Processing:5,round:11
# Processing:5,round:12
# Processing:5,round:13
# Processing:5,round:14
# Processing:5,round:15
# Processing:5,round:16
# ------------------------------------ 5
# max [1.1577648479682237, 1.2848601520184022, 1.2163598889506633, 1.6086004686014004, 74.99881775179135, 28673639.041653883]
# min [0.8969902167279181, 0.8429354475981796, 0.8478876438870043, 0.7759060508933959, 1.0, 223.95117427587047]
# ------------------------------------
# Processing:6,round:1
# Processing:6,round:2
# Processing:6,round:3
# Processing:6,round:4
# Processing:6,round:5
# Processing:6,round:6
# Processing:6,round:7
# Processing:6,round:8
# Processing:6,round:9
# Processing:6,round:10
# Processing:6,round:11
# Processing:6,round:12
# Processing:6,round:13
# Processing:6,round:14
# Processing:6,round:15
# Processing:6,round:16
# ------------------------------------ 6
# max [1.159277958985498, 1.3465358069763105, 1.1123591920180758, 1.2034676776056585, 6.06079992769946, 22786679.554911118]
# min [0.8981625150419499, 0.8833977911454565, 0.7753919074805281, 0.5805707293772117, 0.2907918552387177, 687.5922162224401]
# ------------------------------------
# Processing:7,round:1
# Processing:7,round:2
# Processing:7,round:3
# Processing:7,round:4
# Processing:7,round:5
# Processing:7,round:6
# Processing:7,round:7
# Processing:7,round:8
# Processing:7,round:9
# Processing:7,round:10
# Processing:7,round:11
# Processing:7,round:12
# Processing:7,round:13
# Processing:7,round:14
# Processing:7,round:15
# Processing:7,round:16
# ------------------------------------ 7
# max [1.2242533429578557, 1.4385935219348034, 1.1223295515226608, 1.4149601305159947, 6.312593845303684, 1040904.461531258]
# min [0.9485028616620992, 0.9437925364939124, 0.7823419431614498, 0.682470740609048, 0.44718279518407855, 132.468815556952]
# ------------------------------------
# Processing:8,round:1
# Processing:8,round:2
# Processing:8,round:3
# Processing:8,round:4
# Processing:8,round:5
# Processing:8,round:6
# Processing:8,round:7
# Processing:8,round:8
# Processing:8,round:9
# Processing:8,round:10
# Processing:8,round:11
# Processing:8,round:12
# Processing:8,round:13
# Processing:8,round:14
# Processing:8,round:15
# Processing:8,round:16
# ------------------------------------ 8
# max [1.2154327771626054, 1.4188694706028686, 1.117941834917217, 1.4352412769356397, 48.53525628787877, 1297775.5705423418]
# min [0.9416690376448739, 0.9308525406588413, 0.7792833987878408, 0.6922984446278926, 0.8206021322052953, 272.0317514011117]
# ------------------------------------
# Processing:9,round:1
# Processing:9,round:2
# Processing:9,round:3
# Processing:9,round:4
# Processing:9,round:5
# Processing:9,round:6
# Processing:9,round:7
# Processing:9,round:8
# Processing:9,round:9
# Processing:9,round:10
# Processing:9,round:11
# Processing:9,round:12
# Processing:9,round:13
# Processing:9,round:14
# Processing:9,round:15
# Processing:9,round:16
# ------------------------------------ 9
# max [1.2880983039896463, 1.5242686295395835, 1.0501749982814914, 1.33158242313513, 6.647287582188896, 66260.05979470129]
# min [0.9979674014893294, 1.0, 0.7320451891340272, 0.6422659499319793, 0.4041042614075278, 151.0126532904519]
# ------------------------------------
# Processing:10,round:1
# Processing:10,round:2
# Processing:10,round:3
# Processing:10,round:4
# Processing:10,round:5
# Processing:10,round:6
# Processing:10,round:7
# Processing:10,round:8
# Processing:10,round:9
# Processing:10,round:10
# Processing:10,round:11
# Processing:10,round:12
# Processing:10,round:13
# Processing:10,round:14
# Processing:10,round:15
# Processing:10,round:16
# ------------------------------------ 10
# max [1.2168278355033408, 1.4708509977104494, 1.0, 1.0, 3.592920378406198, 1027302.8745897898]
# min [0.9427498734342834, 0.964954963913638, 0.6970697172680244, 0.48244740227256894, 0.16441757733878826, 918.412502311066]
# ------------------------------------
# Processing:11,round:1
# Processing:11,round:2
# Processing:11,round:3
# Processing:11,round:4
# Processing:11,round:5
# Processing:11,round:6
# Processing:11,round:7
# Processing:11,round:8
# Processing:11,round:9
# Processing:11,round:10
# Processing:11,round:11
# Processing:11,round:12
# Processing:11,round:13
# Processing:11,round:14
# Processing:11,round:15
# Processing:11,round:16
# ------------------------------------ 11
# max [1.1324964008507916, 1.3030285779468271, 1.2148397375808875, 1.5762435747975876, 42.53449369021888, 90369979.16370203]
# min [0.8774132275871445, 0.8548548369066374, 0.8468279924014702, 0.7602865523890373, 0.9474945959877614, 223.21613881572875]
# ------------------------------------
# Processing:12,round:1
# Processing:12,round:2
# Processing:12,round:3
# Processing:12,round:4
# Processing:12,round:5
# Processing:12,round:6
# Processing:12,round:7
# Processing:12,round:8
# Processing:12,round:9
# Processing:12,round:10
# Processing:12,round:11
# Processing:12,round:12
# Processing:12,round:13
# Processing:12,round:14
# Processing:12,round:15
# Processing:12,round:16
# ------------------------------------ 12
# max [1.2000779987532597, 1.4107235117353598, 1.1358575166631801, 1.4427891351146251, 5.886575183553394, 4292935.256180332]
# min [0.9297727652391442, 0.9255083997557179, 0.7917718779971633, 0.6958985554509461, 0.47039160090006377, 136.93106023313794]
# ------------------------------------
# Processing:13,round:1
# Processing:13,round:2
# Processing:13,round:3
# Processing:13,round:4
# Processing:13,round:5
# Processing:13,round:6
# Processing:13,round:7
# Processing:13,round:8
# Processing:13,round:9
# Processing:13,round:10
# Processing:13,round:11
# Processing:13,round:12
# Processing:13,round:13
# Processing:13,round:14
# Processing:13,round:15
# Processing:13,round:16
# ------------------------------------ 13
# max [1.13340787763375, 1.3093153400230708, 1.124904291948591, 1.2176696661055624, 7.14686770967271, 74210335.15336536]
# min [0.8781194035938897, 0.8589793431421529, 0.7841367167421914, 0.5874288854224694, 0.33866723607072863, 714.8557673162022]
# ------------------------------------
# Processing:14,round:1
# Processing:14,round:2
# Processing:14,round:3
# Processing:14,round:4
# Processing:14,round:5
# Processing:14,round:6
# Processing:14,round:7
# Processing:14,round:8
# Processing:14,round:9
# Processing:14,round:10
# Processing:14,round:11
# Processing:14,round:12
# Processing:14,round:13
# Processing:14,round:14
# Processing:14,round:15
# Processing:14,round:16
# ------------------------------------ 14
# max [1.2159567526878232, 1.33825246991133, 1.1543422228969735, 1.586681022065343, 43.06876656427711, 1256110.4810549314]
# min [0.9420749930690259, 0.8779637857284224, 0.804657006945336, 0.7653152951497146, 1.0, 240.3922800645655]
# ------------------------------------
# Processing:15,round:1
# Processing:15,round:2
# Processing:15,round:3
# Processing:15,round:4
# Processing:15,round:5
# Processing:15,round:6
# Processing:15,round:7
# Processing:15,round:8
# Processing:15,round:9
# Processing:15,round:10
# Processing:15,round:11
# Processing:15,round:12
# Processing:15,round:13
# Processing:15,round:14
# Processing:15,round:15
# Processing:15,round:16
# ------------------------------------ 15
# max [1.2170042572468873, 1.36435836166255, 1.0681948203732023, 1.2108360348914726, 28.411544169249392, 978033.3602410036]
# min [0.9428865579935503, 0.8950905667922211, 0.7446062614247162, 0.5841235089574257, 1.0, 665.6250419529019]
# ------------------------------------
# Processing:16,round:1
# Processing:16,round:2
# Processing:16,round:3
# Processing:16,round:4
# Processing:16,round:5
# Processing:16,round:6
# Processing:16,round:7
# Processing:16,round:8
# Processing:16,round:9
# Processing:16,round:10
# Processing:16,round:11
# Processing:16,round:12
# Processing:16,round:13
# Processing:16,round:14
# Processing:16,round:15
# Processing:16,round:16
# ------------------------------------ 16
# max [1.2907218232452646, 1.4564187997865958, 1.0775731171644312, 1.4425424622445828, 6.105472256233656, 73794.90847549384]
# min [1.0, 0.9554871213063152, 0.7511435881174338, 0.6957642370666062, 0.49271864355528633, 62.671729462447274]
# ------------------------------------

# %%
ma=[0,0,0,0,0,0]
mi=[2,2,2,2,2,9999999]

def getMax_min(max_result,min_result):
    
    for i in range(len(max_result)):
        
        _max = max_result[i]
        
        for _i in range(0,6):
            if(_max[_i]>ma[_i]):
                ma[_i]=_max[_i]
    
    for i in range(len(min_result)):
        _min = min_result[i]
        for _i in range(0,6):
            if(_min[_i]<mi[_i]):
                mi[_i]=_min[_i]

# %%
getMax_min(max_result,min_result)
print("max:",ma)
print("min:",mi)
# Out:
# max: [1.2907218232452646, 1.4564187997865958, 1.0775731171644312, 1.4425424622445828, 6.105472256233656, 73794.90847549384]
# min: [1.0, 0.9554871213063152, 0.7511435881174338, 0.6957642370666062, 0.49271864355528633, 62.671729462447274]
