# %% [markdown]
# ## 异常检测试验|sp_string

# %% [markdown]
# ### 1、导入库

# %%
#引入库
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %% [markdown]
# ### 2、序列对齐

# %%
# 计算曲线拟合R2值

from sklearn.metrics import r2_score
def caculateMse_R2(x,y,p):
    y_pre = [p(i) for i in x]
#     mse = get_mse(y, y_pre)  # 0.66
    score = r2_score(y, y_pre, multioutput='raw_values')
#     print(score[0])
    return score[0]


# 将单独的x,y对齐合并成list，[[x1,y1],[x2,y2],...,[xn,yn]]

def list_set(x,y):
    list=[]
    for i in range(0,len(x)):
        list.append([x[i],y[i]])
    return list

# 数据集修整，将短的序列拓展，其值为最后一项。防止拟合过度

def data_set_fix(list,x):
    n=0;
    data=0;
    for i in range(0,len(list)):
        if n==0:
            if list[i][0]==x:
                n=1
                data=list[i][1]
        else:
            list[i][1]=data
    
    return list

# %%
# 单一序列数据对齐算法
def align_data_singe(x,y,x1,n):
    
#     print("----------")
    # 曲线拟合,R2小于0.9则重新拟合
    while True:
        coef = np.polyfit(x,y, n)
        poly_fit = np.poly1d(coef)
        R2 = caculateMse_R2(x,y,poly_fit)
#         print(R2,n)
        if n>=19:
            break
        if R2>0.9:
            break
        else:
            n=n+1 
        
    
    # 数据list
    data_set = list_set(x,y)
    
    # 数据对齐
    for i in range(0,len(x1)):
         data_set.append([x1[i],poly_fit(x1[i])])
    
    # 排序
    data_set.sort();
#     print("数据长度",len(data_set))
    
    # 返回序列
#     print("----------")
    return data_set
    
    
# 双序列数据对其
def align_data(x1,y1,x2,y2):
    timeseries1 = align_data_singe(x1,y1,x2,6)
    timeseries2 = align_data_singe(x2,y2,x1,6)
    
    
    
    # 数据修整（短数据向长数据对齐时，为当前尾均值）
    if(len(x1)>len(x2)):
        timeseries2 = data_set_fix(timeseries2,x2[-1])
    else:
        timeseries1 = data_set_fix(timeseries1,x1[-1])
    
    return timeseries1,timeseries2

# %% [markdown]
# ### 3、序列属性及特征评估算法

# %%
# DTW距离

# 计算权重
def calculate_attenuate_weight(seqLen1, seqLen2, com_ls):
    weight = 0
    for comlen in com_ls:
        weight = weight + comlen / seqLen1 * comlen / seqLen2
    return 1 - weight


# DTW距离
def DTWDistance(s1, s2):
    # 取较大的标准差
    sdt = np.std(s1, ddof=1) if np.std(s1, ddof=1) > np.std(s2, ddof=1) else np.std(s2, ddof=1)
    # print("两个序列最大标准差:" + str(sdt))
    l1 = len(s1)
    l2 = len(s2)
    paths = np.full((l1 + 1, l2 + 1), np.inf)  # 全部赋予无穷大
    sub_matrix = np.full((l1, l2), 0)  # 全部赋予0
    max_sub_len = 0

    paths[0, 0] = 0
    for i in range(l1):
        for j in range(l2):
            d = s1[i] - s2[j]
            cost = d ** 2
            paths[i + 1, j + 1] = cost + min(paths[i, j + 1], paths[i + 1, j], paths[i, j])
            if np.abs(s1[i] - s2[j]) < sdt:
                if i == 0 or j == 0:
                    sub_matrix[i][j] = 1
                else:
                    sub_matrix[i][j] = sub_matrix[i - 1][j - 1] + 1
                    max_sub_len = sub_matrix[i][j] if sub_matrix[i][j] > max_sub_len else max_sub_len

    paths = np.sqrt(paths)
    s = paths[l1, l2]

    return s

# %%
#LB_Keogh

def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return math.sqrt(LB_sum)

# %%
# 相似度规整
def Dtw_LB_conter(data1,data2,r):
    l=LB_Keogh(data1,data2,r)+DTWDistance(data1,data2)
    return l/2

def getMin(a,b):
    if a<b:
        return a
    else:
        return b

# %%
# 基于滑动窗口的基础数据评分
def timeseries_score(s1,s2,w,r):
    # s1序列1，s2序列2，w普通滑窗大小,r斜率滑窗大小
    
    
    # 时间比
    time_s1_s2 = s2[0][len(s2[0])-1]/s1[0][len(s1[0])-1]
#     print("s2:",s2[0][len(s2[0])-1])
#     print("s1:",s1[0][len(s1[0])-1])
#     print(s2[0][len(s2[0])-1]/s1[0][len(s1[0])-1])
    
    # 滑窗时间比
    time_sum=0;
    for i in range(math.ceil(len(s1[0])/w)):
        s1_time = sum(s1[0][i:i+w])
        s2_time = sum(s2[0][i:i+w])
        i=i+w
        time_sum =time_sum + s2_time/s1_time    

    time_sum = time_sum/math.ceil(len(s1[0])/w)
#     print(time_sum)
    
    
    # 均值比
    heartbeat_s1 = (sum(s1[1])/len(s1[1]))
    heartbeat_s1_s2 = sum(s2[1])/len(s2[1])/(sum(s1[1])/len(s1[1]))
#     print(sum(s2[1])/len(s2[1])/(sum(s1[1])/len(s1[1])))
    
    # 滑窗均值比
    heartbeat_sum=0;
    for i in range(math.ceil(len(s1[1])/w)):
        s1_heartbeat = sum(s1[1][i:i+w])
        s2_heartbeat = sum(s2[1][i:i+w])
        i=i+w
        heartbeat_sum =heartbeat_sum + s2_heartbeat/s1_heartbeat    

    heartbeat_sum = heartbeat_sum/math.ceil(len(s1[1])/w)
#     print(heartbeat_sum)
    
    # 滑窗斜率比
    slope_sum=0;
    for i in range(math.ceil(getMin(len(s1[1])/r,len(s2[1])/r))):
        
        k=i+r
        if(k>len(s1[1])):
            k=len(s1[1])  
        
        s1_slope = (s1[1][i]-s1[1][k])/(s1[0][i]-s1[0][k])
        s2_slope = (s2[1][i]-s2[1][k])/(s2[0][i]-s2[0][k])
#         print(abs(s2_slope/s1_slope) )
        
        i=i+r
        slope_sum =slope_sum + abs(s2_slope/s1_slope)    

    slope_sum = slope_sum/math.ceil(math.ceil(len(s1[1])/r))
#     print(slope_sum)

    return [time_s1_s2,time_sum,heartbeat_s1,heartbeat_s1_s2,heartbeat_sum,slope_sum]

# %%
def similar_all(x1,y1,x2,y2,tS1,tS2):
    x_p1 =[ tS1[i][0] for i in range(0,len(tS1))]
    y_p1 =[ tS1[i][1] for i in range(0,len(tS1))]
    x_p2 =[ tS2[i][0] for i in range(0,len(tS2))]
    y_p2 =[ tS2[i][1] for i in range(0,len(tS2))]
    
    feature = timeseries_score([x1,y1],[x2,y2],100,20)
    distent = Dtw_LB_conter(y_p1,y_p2,100)
          
    return feature,distent

# %% [markdown]
# ### 4、异常检测函数

# %%
# 异常检测

min_time_standard = 0.817649
max_time_standard = 1.055358
min_hr_standard   = 0.981820
max_hr_standard   = 1.408497


# 特征检测，1表示异常
def distent_check(h_distence):
    #h_standard = 415361526.2198037;
    h_standard = 18383645284.886333
                 
    if h_distence<h_standard:
        return 2;
    else:
        return 1;
    

def dataseries_check(feature):
    
    #----------------------------------------
    # 时间关系
    time_check={}
    if feature[0]>min_time_standard*0.9 and feature[0]<max_time_standard*1.1:
        # 正常
        time_check[0]=2
    else:
        # 异常,忙等、死锁、资源竞争
        time_check[0]=1
    
    # 局部时间与整体时间关系：
    if feature[0]/feature[1]>0.90:
        # 正常
        time_check[1]=2
    else:
        # 异常，局部异常较大
        time_check[1]=1
    
   #-------------------------------------------- 
   # 心率均值
    heart={}
    if feature[3]>min_hr_standard*0.9 and feature[3]<max_hr_standard*1.1 :
        # 正常
        heart[0]=2
    else:
        # 异常，内存泄漏|忙等
        heart[0]=1
    
    if feature[3]/feature[4]>0.90:
        # 正常
        heart[1]=2
    else:
        # 异常，局部异常较大
        heart[1]=1
    
     #-------------------------------------------- 
    return [time_check,heart]

# %%
def judge(feature):
    
    judge_distence = distent_check(feature[1])
    judge_dataseries = dataseries_check(feature[0])
#     print("distence:",judge_distence)
#     print("series:",judge_dataseries)

    
    assis=0;
    check=0;
    # 0:正常
    # 1：内存泄漏|忙等
    # 2：死锁，资源竞争|中断
    
    # 距离在正常范围内，进入辅助判别
    print("judge_distence = "+str(judge_distence))
    print(judge_dataseries)
    if(judge_distence==2):
        t=0
        # 平均时间比值
        print("judge_dataseries[0][0]:"+str(judge_dataseries[0][0]))
        print("feature[0][0]"+str(feature[0][0]))
        print("min_time_standard"+str(min_time_standard))  
        print("judge_dataseries[0][0]",judge_dataseries[0][0])
        if judge_dataseries[0][0] == 1 and feature[0][0]<min_time_standard*0.9:
            t=2
            check=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0] = "+str(feature[0][0]))
        # 平均心率比值    
        if judge_dataseries[1][0]==1 and  t!=2 and feature[0][0]>max_time_standard*1.1:
            check=1
            if judge_dataseries[1][1]==1:
                assis=1;
    
    # 距离在不正常范围内，辅助判别
    elif judge_distence==1:
        t=0
        check=1
        if judge_dataseries[0][0]==1 and feature[0][0]<min_time_standard*0.9:
            check=2
            t=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0]"+str(feature[0][0]))
        print("max_time_standard"+str(max_time_standard))  
        if judge_dataseries[1][0]==1 and t!=2 and feature[0][0]>max_time_standard*1.1:
            if t==1:
                check=1
            if judge_dataseries[1][1]==1:
                assis=1;    
    
    #-------------------------------------------------
#   print(check,assis)
    if(check==0 and assis==0):
        print("正常：","两线程序列吻合度高，线程状态正常")
    elif(check==0 and assis==1):
        print("正常：","两线程序列吻合度高，线程状态正常,但局部震荡较严重")
    elif(check==1 and assis==0):
        print("内存泄漏：","两线程序列吻合度低，线程状态异常，为内存泄漏")
    elif(check==1 and assis==1):
        print("内存泄漏：","两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重")    
    elif(check==2 and assis==0):
        print("中断：","两线程序列吻合度低，线程状态异常，为中断执行")
    elif(check==2 and assis==1):
        print("中断：","两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重")
    return [check,assis]

# %% [markdown]
# ### 5、实验

# %% [markdown]
# #### 5.1 导入数据

# %%
data = pd.read_excel('./data8_jacobi/jacobi_std_normal.xlsx',hearder=None,sheet_name=None)
# 数据x
x = data['19']['0.3'].copy()[0:999]
# 数据y
y = data['10']['0.3'].copy()[0:999]
# 转成array
x = np.array(x)
y = np.array(y)

# %%
# sp正常数据
normal = pd.read_excel('./data8_jacobi/jacobi_std_normal.xlsx',hearder=None,sheet_name=None)
len(normal)
# Out:
# 31

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('./data8_jacobi/jacobi_std_normal.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['0.3'].copy()[0:999]
    y6 = data[i]['0.4'].copy()[0:999]
    label_name = '测试序列'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()

# %% [markdown]
# #### 5.2 正常实验

# %%
# 正常测试实验

# 序列特征
SeriesFeature=[]
# 序列结果
SeriesResult=[]

def normal_lab():
    
    for i in normal:
        title_times = "进行至序列号："+str(i)+"："
        print(title_times)
        x2 = normal[i]['0.3'].copy()[0:999]
        y2 = normal[i]['0.4'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature.append(feature)
        
        check=judge(feature)
        
        SeriesResult.append(check)
    
normal_lab()
# Out:
# 进行至序列号：1：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.1829430121927091
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.1829430121927091
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1208919587601316
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1208919587601316
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：3：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.059171777119104
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.059171777119104
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：4：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0578763241821076
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0578763241821076
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：5：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0217472177261826
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0217472177261826
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：6：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0204136143741753
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0204136143741753
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：7：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9662567139368892
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9662567139368892
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：8：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9732689741626495
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9732689741626495
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：9：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9183639234123373
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9183639234123373
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：10：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9721531490963836
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9721531490963836
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：11：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0445446107413847
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0445446107413847
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：12：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.985721772602821
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.985721772602821
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：13：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0437045970267784
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0437045970267784
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：14：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9728495767451116
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9728495767451116
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：15：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9720122219364855
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9720122219364855
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：16：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9164972582693558
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9164972582693558
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：17：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9444483105154542
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9444483105154542
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：18：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9973095522976797
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9973095522976797
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：19：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：20：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.915114560301321
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.915114560301321
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：21：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9699808126247201
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9699808126247201
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：22：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9699808126247201
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9699808126247201
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：23：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9706665635059147
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9706665635059147
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：24：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.053983042958257
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.053983042958257
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：25：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.054012218922716
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.054012218922716
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：26：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.945433093174808
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.945433093174808
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：28：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.9456073466611107
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.9456073466611107
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：29：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]0.8910476245393117
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 0.8910476245393117
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：30：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0725957345398258
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0725957345398258
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：31：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0722525196644226
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0722525196644226
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：32：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0099928321140585
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0099928321140585
# 正常： 两线程序列吻合度高，线程状态正常

# %%
def precisionRate(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("准确率:",(len(result)-num)/len(result))
precisionRate(SeriesResult)
# Out:
# 准确率: 0.967741935483871

# %% [markdown]
# #### 5.3、内存泄漏检查试验

# %%
# sp泄露数据
abnormal = pd.read_excel('./data8_jacobi/jacobi_std_abn.xlsx',hearder=None,sheet_name=None)
len(abnormal)
# Out:
# 40

# %%
# 正常测试实验

# 序列特征
SeriesFeature1=[]
# 序列结果
SeriesResult1=[]

def abnormal_lab():
    
    for i in abnormal:
        title_times = "进行至序列号："+str(i)+"："
        print(title_times)
        x2 = abnormal[i]['time'].copy()[0:999]

        y2 = abnormal[i]['heartrate'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature1.append(feature)
        
        check=judge(feature)
        
        SeriesResult1.append(check)
    
abnormal_lab()
# Out:
# 进行至序列号：2_1：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.190449114060499
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.190449114060499
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_2：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.1871815757585082
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.1871815757585082
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_3：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1239590145226308
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1239590145226308
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_4：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.215611935665399
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.215611935665399
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_5：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2144164977082776
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2144164977082776
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_6：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.144309884887217
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.144309884887217
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_7：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0991202091547903
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0991202091547903
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_8：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.1625031841941997
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.1625031841941997
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_9：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.1633134767914768
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.1633134767914768
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_10：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2011750327823307
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2011750327823307
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_11：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2009581185124591
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2009581185124591
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_12：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3036956123931824
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3036956123931824
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_13：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2316885709518492
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2316885709518492
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_14：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2968855010232339
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2968855010232339
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_15：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1378780221790097
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1378780221790097
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_16：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1466596994758402
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1466596994758402
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_17：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.078152997183879
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.078152997183879
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_18：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2096916063527445
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2096916063527445
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_19：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.20999837827307
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.20999837827307
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_20：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1434506622483638
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1434506622483638
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_21：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2165250050075633
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2165250050075633
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_22：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2131641427057365
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2131641427057365
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_23：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1530752898851673
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1530752898851673
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_24：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2279250566829125
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2279250566829125
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_25：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.233413547778095
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.233413547778095
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_26：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.1668620876846196
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.1668620876846196
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_27：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.1858814890221152
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.1858814890221152
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_28：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.1860204464315485
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.1860204464315485
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_29：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1236771704887378
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1236771704887378
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_30：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2043810253824565
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2043810253824565
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_31：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2043810253824565
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2043810253824565
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_32：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:2
# feature[0][0]1.1386538312857708
# min_time_standard0.817649
# judge_dataseries[0][0] 2
# feature[0][0] = 1.1386538312857708
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_33：
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.9221326834919117
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.9221326834919117
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_34：
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.9216005680040327
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.9216005680040327
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_35：
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.9207452488654482
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.9207452488654482
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_36：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.919205886305602
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.919205886305602
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_37：
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.9142385870690881
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.9142385870690881
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_38：
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.9142385870690881
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.9142385870690881
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_39：
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.908074085843052
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.908074085843052
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：2_40：
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/wwd/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.913482300606622
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 1.913482300606622
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('./data8_jacobi/jacobi_std_abn.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['time'].copy()[0:999]
    y6 = data[i]['heartrate'].copy()[0:999]
    label_name = '测试序列'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()
# Out:
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def precisionRate1(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("准确率:",(num/len(result)))
precisionRate1(SeriesResult1)
# Out:
# 准确率: 0.75

# %% [markdown]
# ### 5.4 中断测试

# %%
# sp泄露数据
shutdown = pd.read_excel('./data8_jacobi/jacobi_std_shut.xlsx',hearder=None,sheet_name=None)
len(shutdown)
# Out:
# 31

# %%
# 中断测试实验

# 序列特征
SeriesFeature2=[]
# 序列结果
SeriesResult2=[]

def shutdown_lab():
    for i in shutdown:
        title_times = "进行至序列号："+str(i)+"："
        print(title_times)
        x2 = shutdown[i]['time'].copy()[0:len(shutdown[i])]

        y2 = shutdown[i]['heartrate'].copy()[0:len(shutdown[i])]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature2.append(feature)
        
        check=judge(feature)
        
        SeriesResult2.append(check)

    
shutdown_lab()
# Out:
# 进行至序列号：3_1：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.18272725508694873
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.18272725508694873
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_2：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.18275297498792858
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.18275297498792858
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_3：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.15842888650268505
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.15842888650268505
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_4：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.19417915800038607
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.19417915800038607
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_5：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.19418790616106726
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.19418790616106726
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_6：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.16968336693283617
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.16968336693283617
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_7：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.16896084394766114
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.16896084394766114
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_8：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.168934501749537
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.168934501749537
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_9：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.1482189138288841
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.1482189138288841
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_10：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.12505548151905282
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.12505548151905282
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行
# 进行至序列号：3_11：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.10398439735456239
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.10398439735456239
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_12：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.10489456092906968
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.10489456092906968
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_13：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.10145403430687128
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.10145403430687128
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_14：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.18992142151100094
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.18992142151100094
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_15：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.1896225594502448
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.1896225594502448
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_16：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.16438954684183094
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.16438954684183094
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_17：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.18822010740509276
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.18822010740509276
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_18：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.18820965692743008
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.18820965692743008
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_19：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.16196592575471516
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.16196592575471516
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_20：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.22830616996869788
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.22830616996869788
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_21：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.22831947992745333
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.22831947992745333
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_22：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.2102375409515879
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.2102375409515879
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_23：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.17807729653631005
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.17807729653631005
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_24：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.178068702664177
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.178068702664177
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_25：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.15253932232653575
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.15253932232653575
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_26：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.1088742797405564
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.1088742797405564
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_27：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.11153229599005143
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.11153229599005143
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_28：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.09915330404837258
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.09915330404837258
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_29：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.048725732680700316
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.048725732680700316
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_30：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.045252080307209896
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.045252080307209896
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_31：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]0.032637700613491895
# min_time_standard0.817649
# judge_dataseries[0][0] 1
# feature[0][0] = 0.032637700613491895
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重

# %%
def precisionRate2(result):
    num=0
    for i in result:
        if i[0]==2:
            num=num+1
    print("准确率:",(num/len(result)))
precisionRate2(SeriesResult2)
# Out:
# 准确率: 1.0

# %% [markdown]
# ### 5.5 总体

# %%
# 总体预测和真实结果
def resultValue():
    Result_all_pre=[]
    Result_all_true=[]
    # 正常预测
    for i in SeriesResult:
        Result_all_pre.append(i[0])
        Result_all_true.append(0)

    # 内存泄漏预测
    for i in SeriesResult1:
        Result_all_pre.append(i[0])
        Result_all_true.append(1)

    # 中断预测    
    for i in SeriesResult2:
        Result_all_pre.append(i[0])
        Result_all_true.append(2)
    
    return [Result_all_pre,Result_all_true]

# %%
from sklearn.metrics import classification_report

# %%
resultvalue = resultValue()
acc_num=0
for i in range(0,100):
    if(resultvalue[0][i]==resultvalue[1][i]):
        acc_num=acc_num+1

print("accuracy:",acc_num/len(resultvalue[0]))

print(classification_report(resultvalue[1], resultvalue[0], labels=[0, 1, 2]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-9076a5c997c3> in <module>
#       2 acc_num=0
#       3 for i in range(0,100):
# ----> 4     if(resultvalue[0][i]==resultvalue[1][i]):
#       5         acc_num=acc_num+1
#       6
#
# IndexError: list index out of range
