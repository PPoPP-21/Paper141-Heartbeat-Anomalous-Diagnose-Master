# %% [markdown]
# # Anomaly detection test|NPB_bt

# %% [markdown]
# ### Import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Sequence alignment

# %%
def caculateMse_R2(x,y,p):
    y_pre = [p(i) for i in x]
    score = r2_score(y, y_pre, multioutput='raw_values')
    return score[0]

def list_set(x,y):
    list=[]
    for i in range(0,len(x)):
        list.append([x[i],y[i]])
    return list

def data_set_fix(list,x):
    n=0;
    data=0;
    for i in range(0,len(list)):
        if n==0:
            if list[i][0]==x:
                n=1
                data=list[i][1]
        else:
            list[i][1]=data
    
    return list

# %%
def align_data_singe(x,y,x1,n):
    
    while True:
        coef = np.polyfit(x,y, n)
        poly_fit = np.poly1d(coef)
        R2 = caculateMse_R2(x,y,poly_fit)
        if n>=19:
            break
        if R2>0.9:
            break
        else:
            n=n+1 
        
    
    data_set = list_set(x,y)
    
    for i in range(0,len(x1)):
         data_set.append([x1[i],poly_fit(x1[i])])
    
    data_set.sort();
    
    return data_set
    
def align_data(x1,y1,x2,y2):
    timeseries1 = align_data_singe(x1,y1,x2,6)
    timeseries2 = align_data_singe(x2,y2,x1,6)
    
    if(len(x1)>len(x2)):
        timeseries2 = data_set_fix(timeseries2,x2[-1])
    else:
        timeseries1 = data_set_fix(timeseries1,x1[-1])
    
    return timeseries1,timeseries2

# %% [markdown]
# ### Sequence attribute and feature evaluation algorithm

# %%
def calculate_attenuate_weight(seqLen1, seqLen2, com_ls):
    weight = 0
    for comlen in com_ls:
        weight = weight + comlen / seqLen1 * comlen / seqLen2
    return 1 - weight

def DTWDistance(s1, s2):
    sdt = np.std(s1, ddof=1) if np.std(s1, ddof=1) > np.std(s2, ddof=1) else np.std(s2, ddof=1)
    l1 = len(s1)
    l2 = len(s2)
    paths = np.full((l1 + 1, l2 + 1), np.inf)
    sub_matrix = np.full((l1, l2), 0)
    max_sub_len = 0

    paths[0, 0] = 0
    for i in range(l1):
        for j in range(l2):
            d = s1[i] - s2[j]
            cost = d ** 2
            paths[i + 1, j + 1] = cost + min(paths[i, j + 1], paths[i + 1, j], paths[i, j])
            if np.abs(s1[i] - s2[j]) < sdt:
                if i == 0 or j == 0:
                    sub_matrix[i][j] = 1
                else:
                    sub_matrix[i][j] = sub_matrix[i - 1][j - 1] + 1
                    max_sub_len = sub_matrix[i][j] if sub_matrix[i][j] > max_sub_len else max_sub_len

    paths = np.sqrt(paths)
    s = paths[l1, l2]

    return s

# %%
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return math.sqrt(LB_sum)

# %%
def Dtw_LB_conter(data1,data2,r):
    l=LB_Keogh(data1,data2,r)+DTWDistance(data1,data2)
    return l/2

def getMin(a,b):
    if a<b:
        return a
    else:
        return b

# %%
def timeseries_score(s1,s2,w,r):
    
    time_s1_s2 = s2[0][len(s2[0])-1]/s1[0][len(s1[0])-1]
    
    time_sum=0;
    for i in range(math.ceil(len(s1[0])/w)):
        s1_time = sum(s1[0][i:i+w])
        s2_time = sum(s2[0][i:i+w])
        i=i+w
        time_sum =time_sum + s2_time/s1_time    

    time_sum = time_sum/math.ceil(len(s1[0])/w)
    
    heartbeat_s1 = (sum(s1[1])/len(s1[1]))
    heartbeat_s1_s2 = sum(s2[1])/len(s2[1])/(sum(s1[1])/len(s1[1]))
    
    heartbeat_sum=0;
    for i in range(math.ceil(len(s1[1])/w)):
        s1_heartbeat = sum(s1[1][i:i+w])
        s2_heartbeat = sum(s2[1][i:i+w])
        i=i+w
        heartbeat_sum =heartbeat_sum + s2_heartbeat/s1_heartbeat    

    heartbeat_sum = heartbeat_sum/math.ceil(len(s1[1])/w)
    
    slope_sum=0;
    for i in range(math.ceil(getMin(len(s1[1])/r,len(s2[1])/r))):
        
        k=i+r
        if(k>len(s1[1])):
            k=len(s1[1])  
        
        s1_slope = (s1[1][i]-s1[1][k])/(s1[0][i]-s1[0][k])
        s2_slope = (s2[1][i]-s2[1][k])/(s2[0][i]-s2[0][k])
        
        i=i+r
        slope_sum =slope_sum + abs(s2_slope/s1_slope)    

    slope_sum = slope_sum/math.ceil(math.ceil(len(s1[1])/r))

    return [time_s1_s2,time_sum,heartbeat_s1,heartbeat_s1_s2,heartbeat_sum,slope_sum]

# %%
def similar_all(x1,y1,x2,y2,tS1,tS2):
    x_p1 =[ tS1[i][0] for i in range(0,len(tS1))]
    y_p1 =[ tS1[i][1] for i in range(0,len(tS1))]
    x_p2 =[ tS2[i][0] for i in range(0,len(tS2))]
    y_p2 =[ tS2[i][1] for i in range(0,len(tS2))]
    
    feature = timeseries_score([x1,y1],[x2,y2],100,20)
    distent = Dtw_LB_conter(y_p1,y_p2,100)
          
    return feature,distent

# %% [markdown]
# ### Anomaly detection function

# %%
min_time_standard = 0.9453820
max_time_standard = 1.0577734
min_hr_standard   = 0.8571541
max_hr_standard   = 1.1666512

def distent_check(h_distence):
    h_standard =  145343914.2
    if h_distence<h_standard:
        return 2;
    else:
        return 1;

def dataseries_check(feature):
    
    time_check={}
    if feature[0]>min_time_standard*0.9 and feature[0]<max_time_standard*1.1:
        time_check[0]=2
    else:
        time_check[0]=1
    
    if feature[0]/feature[1]>0.90:
        time_check[1]=2
    else:
        time_check[1]=1
    
    heart={}
    if feature[3]>min_hr_standard*0.9 and feature[3]<max_hr_standard*1.1 :
        heart[0]=2
    else:
        heart[0]=1
    
    if feature[3]/feature[4]>0.90:
        heart[1]=2
    else:
        heart[1]=1
    
    return [time_check,heart]

# %%
def judge(feature):
    
    judge_distence = distent_check(feature[1])
    judge_dataseries = dataseries_check(feature[0])
    
    assis=0;
    check=0;
    
    print("judge_distence = "+str(judge_distence))
    print(judge_dataseries)
    if(judge_distence==2):
        t=0
        print("judge_dataseries[0][0]:"+str(judge_dataseries[0][0]))
        print("feature[0][0]:"+str(feature[0][0]))
        print("min_time_standard:"+str(min_time_standard))  
        print("judge_dataseries[0][0]:",judge_dataseries[0][0])
        if judge_dataseries[0][0] == 1 and feature[0][0]<min_time_standard*0.9:
            t=2
            check=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0] = "+str(feature[0][0]))
        if judge_dataseries[1][0]==1 and  t!=2 and feature[0][0]>max_time_standard*1.1:
            check=1
            if judge_dataseries[1][1]==1:
                assis=1;
    
    elif judge_distence==1:
        t=0
        check=1
        if judge_dataseries[0][0]==1 and feature[0][0]<min_time_standard*0.9:
            check=2
            t=2
            if judge_dataseries[0][1]==1:
                assis=1;
        print("feature[0][0]:"+str(feature[0][0]))
        print("max_time_standard:"+str(max_time_standard))  
        if judge_dataseries[1][0]==1 and t!=2 and feature[0][0]>max_time_standard*1.1:
            if t==1:
                check=1
            if judge_dataseries[1][1]==1:
                assis=1;    
    
    if(check==0 and assis==0):
        print("Normal：","Two heartbeat sequences are highly consistent, and the thread status is normal.")
    elif(check==0 and assis==1):
        print("Normal：","Two heartbeat sequences have high consistency. The thread status is normal, yet the local oscillation is intense.")
    elif(check==1 and assis==0):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak.")
    elif(check==1 and assis==1):
        print("Memory leak：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is memory leak with intense local oscillation.")    
    elif(check==2 and assis==0):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown.")
    elif(check==2 and assis==1):
        print("Shutdown：","The heartbeat sequences of two threads have low consistency. The thread status is abnormal, and its status is shutdown with intense local oscillation.")
    return [check,assis]

# %% [markdown]
# ### experiment

# %% [markdown]
# #### 5.1 导入数据

# %%
data = pd.read_excel('./data6_bt_string/bt_std_normal_1.xlsx',hearder=None,sheet_name=None)
# 数据x
x = data['1']['time'].copy()[0:999]
# 数据y
y = data['1']['heartrate'].copy()[0:999]
# 转成array
x = np.array(x)
y = np.array(y)

# %%
# sp正常数据
normal = pd.read_excel('./data6_bt_string/bt_std_normal.xlsx',hearder=None,sheet_name=None)
len(normal)
# Out:
# 31

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('./data6_bt_string/bt_std_normal.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['time'].copy()[0:999]
    y6 = data[i]['heartrate'].copy()[0:999]
    label_name = '测试序列'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()
# Out:
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### 5.2 正常实验

# %%
# 正常测试实验

# 序列特征
SeriesFeature=[]
# 序列结果
SeriesResult=[]

def normal_lab():
    
    for i in normal:
        title_times = "进行至序列号："+str(i)+"："
        print(title_times)
        x2 = normal[i]['time'].copy()[0:999]
        y2 = normal[i]['heartrate'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature.append(feature)
        
        check=judge(feature)
        
        SeriesResult.append(check)
    
normal_lab()
# Out:
# 进行至序列号：1：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.000006020081871
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.000006020081871
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：3：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2759245310405505
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2759245310405505
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：4：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2759320220240373
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2759320220240373
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：5：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0577734443634572
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0577734443634572
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：6：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.032482489029993
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.032482489029993
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：7：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0335105886037241
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0335105886037241
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：8：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3126418216422004
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3126418216422004
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：9：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3126451046339511
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3126451046339511
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：10：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0440735880250533
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0440735880250533
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：11：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0440882288035078
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0440882288035078
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：12：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0440735880250533
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0440735880250533
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：13：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3228813212736181
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3228813212736181
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏,且线程局部震荡较严重
# 进行至序列号：14：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.03039870668625
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.03039870668625
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：15：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.030466330250743
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.030466330250743
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：16：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.321745330308169
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.321745330308169
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：17：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3217465737507719
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3217465737507719
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：18：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]1.9360607711039466
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：19：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]1.9361419133157645
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：20：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# feature[0][0]2.2168012539117834
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：21：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# feature[0][0]2.2032007213422835
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：22：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0424278538300467
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0424278538300467
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：23：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0424087927647776
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0424087927647776
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：24：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3320771934627007
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3320771934627007
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：25：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3320786492003822
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3320786492003822
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：26：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0037898614148342
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0037898614148342
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：27：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0037848573165535
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0037848573165535
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：28：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2957448999860446
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2957448999860446
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：29：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2957462419942198
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2957462419942198
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：30：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.384965667412434
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.384965667412434
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：31：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.384963597535418
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.384963597535418
# 正常： 两线程序列吻合度高，线程状态正常

# %%
def precisionRate(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("准确率:",(len(result)-num)/len(result))
precisionRate(SeriesResult)
# Out:
# 准确率: 0.8387096774193549

# %% [markdown]
# #### 5.3、内存泄漏检查试验

# %%
# sp泄露数据
abnormal = pd.read_excel('./data6_bt_string/bt_std_abn.xlsx',hearder=None,sheet_name=None)
len(abnormal)
# Out:
# 55

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('./data6_bt_string/bt_std_abn.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['time'].copy()[0:999]
    y6 = data[i]['heartrate'].copy()[0:999]
    label_name = '测试序列'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()
# Out:
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 正常测试实验

# 序列特征
SeriesFeature1=[]
# 序列结果
SeriesResult1=[]

def abnormal_lab():

    for i in abnormal:
       
        title_times = "进行至序列号："+str(i)+"："
        print(title_times)
        x2 = abnormal[i]['time'].copy()[0:999]

        y2 = abnormal[i]['heartrate'].copy()[0:999]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature1.append(feature)
        
        check=judge(feature)
        
        SeriesResult1.append(check)
    
abnormal_lab()
# Out:
# 进行至序列号：2_1：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3029225738467294
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3029225738467294
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_2：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3024610670918109
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3024610670918109
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_3：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.6410805352450242
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.6410805352450242
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_4：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.6410805352450242
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.6410805352450242
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_5：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2430212959107252
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2430212959107252
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_6：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.242578038950597
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.242578038950597
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_7：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.5648839344137404
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.5648839344137404
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_8：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.5651857118679333
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.5651857118679333
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_9：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.324221714489899
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.324221714489899
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_10：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3233150022093094
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3233150022093094
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_11：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.6548925819504874
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.6548925819504874
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_12：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.6548246399433766
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.6548246399433766
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_13：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3171645180863047
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3171645180863047
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_14：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3167520818224052
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3167520818224052
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_15：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.655097166168529
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.655097166168529
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_16：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.6547658190426775
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.6547658190426775
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_17：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.366160683081858
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.366160683081858
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_18：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3657489519408978
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3657489519408978
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_19：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.6926222926179224
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.6926222926179224
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_20：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.6928570379010555
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.6928570379010555
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_21：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3993680460756748
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3993680460756748
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_22：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3992337391106082
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3992337391106082
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_23：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.7205631681959166
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.7205631681959166
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_24：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.7206324218833342
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.7206324218833342
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_25：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3814330393951277
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3814330393951277
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_26：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3811688609157435
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3811688609157435
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_27：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.722271157922715
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.722271157922715
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_28：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.7223371058724808
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.7223371058724808
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_29：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.254340596549474
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.254340596549474
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_30：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.2538778615158865
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.2538778615158865
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_31：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.579976067369235
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.579976067369235
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_32：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.5802980886755633
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.5802980886755633
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_33：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# feature[0][0]3.5529131456706504
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_34：
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# /home/wwd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: RankWarning: Polyfit may be poorly conditioned
# judge_distence = 1
# [{0: 2, 1: 1}, {0: 1, 1: 2}]
# feature[0][0]1.0669475335610845
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_35：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0662322128757966
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0662322128757966
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_36：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.359831188715813
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.359831188715813
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_37：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3598739661741457
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3598739661741457
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_38：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0274514671841775
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0274514671841775
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_39：
# judge_distence = 2
# [{0: 2, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0267212934253565
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0267212934253565
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_40：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.304241366038765
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.304241366038765
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_41：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3042070728016082
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3042070728016082
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_42：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]3.884790319259499
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 3.884790319259499
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_43：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]3.887297546883359
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 3.887297546883359
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_44：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]4.500433104706192
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 4.500433104706192
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_45：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]4.500581847736601
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 4.500581847736601
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_46：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]2.0046568062780263
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 2.0046568062780263
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_47：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]2.003344784782604
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_48：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]2.2977279255691028
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_49：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# feature[0][0]2.2977143538480083
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_50：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0588225990598028
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0588225990598028
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_51：
# judge_distence = 2
# [{0: 2, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:2
# feature[0][0]1.0581615576769259
# min_time_standard0.945382
# judge_dataseries[0][0] 2
# feature[0][0] = 1.0581615576769259
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_52：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3705360846512675
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3705360846512675
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_53：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 2, 1: 1}]
# judge_dataseries[0][0]:1
# feature[0][0]1.3704011256370312
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.3704011256370312
# 正常： 两线程序列吻合度高，线程状态正常
# 进行至序列号：2_54：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.589733080942791
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.589733080942791
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：2_55：
# judge_distence = 2
# [{0: 1, 1: 2}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]1.589336703285192
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 1.589336703285192
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('./data6_bt_string/bt_std_abn.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['time'].copy()[0:999]
    y6 = data[i]['heartrate'].copy()[0:999]
    label_name = '测试序列'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()
# Out:
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 35797 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 24207 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/wwd/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def precisionRate1(result):
    num=0
    for i in result:
        if i[0]==1:
            num=num+1
    print("准确率:",(num/len(result)))
precisionRate1(SeriesResult1)
# Out:
# 准确率: 0.7818181818181819

# %% [markdown]
# ### 5.4 中断测试

# %%
# sp泄露数据
shutdown = pd.read_excel('./data6_bt_string/bt_std_shut.xlsx',hearder=None,sheet_name=None)
len(shutdown)
# Out:
# 30

# %%
plt.figure(figsize=(10,5))
data = pd.read_excel('./data6_bt_string/bt_std_shut.xlsx',hearder=None,sheet_name=None)
k=1 
for i in data: 
    x6 = data[i]['time'].copy()[0:len(data[i])]
    y6 = data[i]['heartrate'].copy()[0:len(data[i])]
    label_name = '测试序列'+str(k)
    plt.plot(x6,y6,label=label_name)
    k = k+1
plt.xlabel('Time/us',fontsize=14)
plt.ylabel('Hearrate/HZ',fontsize=14)
plt.legend(loc=0,ncol=3,borderaxespad=0.5)   
plt.show()

# %%
# 中断测试实验

# 序列特征
SeriesFeature2=[]
# 序列结果
SeriesResult2=[]

def shutdown_lab():
    kk = 1
    for i in shutdown:
        title_times = "进行至序列号："+str(i)+"："
        print(title_times)
        x2 = shutdown[i]['time'].copy()[0:len(shutdown[i])]

        y2 = shutdown[i]['heartrate'].copy()[0:len(shutdown[i])]
        x2 = np.array(x2)
        y2 = np.array(y2)
        timeSeries1,timeSeries2 = align_data(x,y,x2,y2)

        feature = similar_all(x,y,x2,y2,timeSeries1,timeSeries2)

        SeriesFeature2.append(feature)
        
        check=judge(feature)
        
        SeriesResult2.append(check)

    
shutdown_lab()
# Out:
# 进行至序列号：3_1：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7227252191859493
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7227252191859493
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_2：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7227729628327272
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7227729628327272
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_3：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7230552091396913
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7230552091396913
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_4：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7230160710255628
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7230160710255628
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_5：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.6154618493840114
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.6154618493840114
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_6：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.6154147274585351
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.6154147274585351
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_7：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.6154417420072836
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.6154417420072836
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_8：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811493691947437
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811493691947437
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_9：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.469461178561891
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.469461178561891
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_10：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.4697239088855605
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.4697239088855605
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_11：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.46905764352735735
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.46905764352735735
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_12：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.46907182938778635
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.46907182938778635
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_13：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.46075660267643137
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.46075660267643137
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_14：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.46071658505412016
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.46071658505412016
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_15：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.46002174326194756
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.46002174326194756
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_16：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.4600427074009567
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.4600427074009567
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_17：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]3.8127219630343623
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：3_18：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]3.8127078226657356
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：3_19：
# judge_distence = 1
# [{0: 1, 1: 2}, {0: 2, 1: 2}]
# feature[0][0]3.812877431269582
# max_time_standard1.0577734
# 内存泄漏： 两线程序列吻合度低，线程状态异常，为内存泄漏
# 进行至序列号：3_20：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811493691947437
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811493691947437
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_21：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 2, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7515664609380771
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7515664609380771
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_22：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7515386578647509
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7515386578647509
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_23：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7518707707692787
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7518707707692787
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_24：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.7299829207092894
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.7299829207092894
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_25：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811929503415881
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811929503415881
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_26：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811531980881252
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811531980881252
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_27：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811493691947437
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811493691947437
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_28：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811493691947437
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811493691947437
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_29：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811929503415881
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811929503415881
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重
# 进行至序列号：3_30：
# judge_distence = 2
# [{0: 1, 1: 1}, {0: 1, 1: 2}]
# judge_dataseries[0][0]:1
# feature[0][0]0.5811531980881252
# min_time_standard0.945382
# judge_dataseries[0][0] 1
# feature[0][0] = 0.5811531980881252
# 中断： 两线程序列吻合度低，线程状态异常，为中断执行,且线程局部震荡较严重

# %%
def precisionRate2(result):
    num=0
    for i in result:
        if i[0]==2:
            num=num+1
    print("准确率:",(num/len(result)))
precisionRate2(SeriesResult2)
# Out:
# 准确率: 0.9

# %% [markdown]
# ### 5.5 总体

# %%
# 总体预测和真实结果
def resultValue():
    Result_all_pre=[]
    Result_all_true=[]
    # 正常预测
    for i in SeriesResult:
        Result_all_pre.append(i[0])
        Result_all_true.append(0)

    # 内存泄漏预测
    for i in SeriesResult1:
        Result_all_pre.append(i[0])
        Result_all_true.append(1)

    # 中断预测    
    for i in SeriesResult2:
        Result_all_pre.append(i[0])
        Result_all_true.append(2)
                   
    return [Result_all_pre,Result_all_true]

# %%
from sklearn.metrics import classification_report

# %%
resultvalue = resultValue()
acc_num=0
for i in range(0,100):
    if(resultvalue[0][i]==resultvalue[1][i]):
        acc_num=acc_num+1

print("accuracy:",acc_num/len(resultvalue[0]))

print(classification_report(resultvalue[1], resultvalue[0], labels=[0, 1, 2]))
# Out:
# accuracy: 0.7155172413793104
#               precision    recall  f1-score   support
#
#            0       0.68      0.84      0.75        31
#            1       0.84      0.78      0.81        55
#            2       1.00      0.90      0.95        30
#
#     accuracy                           0.83       116
#    macro avg       0.84      0.84      0.84       116
# weighted avg       0.84      0.83      0.83       116
